# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2)/ len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 227.099
# The Mean absolute error is 11.564

# %%
HW2
https://www.kaggle.com/datasnaek/youtube-new
Trending YouTube Video Statistics
1.在人手一機的現代，youtube是大多數人連上網會看的平台，想了解使用者對影片的喜好程度及趨勢
2.來自YouTube API.
3.json
4.    a-各種形式的情感分析
    b-根據評論和統計信息對YouTube視頻進行分類。
    c-訓練像RNN這樣的ML算法來生成自己的YouTube評論。
    d-分析哪些因素會影響YouTube視頻的受歡迎程度。
    e-隨時間的統計分析。
HW3
1.哪些地點能以最少時間載最多的客人次數
2.客車在路上都將追蹤行徑路線並記錄，接到客人
3.每五分座標位置、時間、如果載到客人的上下車座標位置跟時間
4.是特定人群眾多的點(火車站、機場)還是一般路上能夠找到目標客人的多
